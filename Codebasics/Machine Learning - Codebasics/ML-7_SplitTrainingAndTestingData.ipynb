# %%
import pandas as pd
df = pd.read_csv("E:\Programming\AI\ML Files\AI ML\ML - Codebasics\carprices7.csv")
df.head()
# Out:
#    mileage  age  price
# 0    69000    6  18000
# 1    35000    3  34000
# 2    57000    5  26100
# 3    22500    2  40000
# 4    46000    4  31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['mileage'], df['price'])
plt.title('Car Mileage Vs Sell Price($)')
plt.xlabel('Car Mileage')
plt.ylabel('Sell Price($)')
# Out:
# Text(0, 0.5, 'Sell Price($)')

# %%
plt.scatter(df['age'], df['price'])
plt.title('Car Age(Year) Vs Sell Price($)')
plt.xlabel('Car Age(Year)')
plt.ylabel('Sell Price($)')
# Out:
# Text(0, 0.5, 'Sell Price($)')

# %%
x = df[['mileage', 'age']]
y = df['price']

# %%
x
# Out:
#     mileage  age
# 0     69000    6
# 1     35000    3
# 2     57000    5
# 3     22500    2
# 4     46000    4
# 5     59000    5
# 6     52000    5
# 7     72000    6
# 8     91000    8
# 9     67000    6
# 10    83000    7
# 11    79000    7
# 12    59000    5
# 13    58780    4
# 14    82450    7
# 15    25400    3
# 16    28000    2
# 17    69000    5
# 18    87600    8
# 19    52000    5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2) 
#add additional parameter: 'random_state' for the same train / test portion
#Example: random_state= 10

# %%
len(x_train)
# Out:
# 16

# %%
len(x_test)
# Out:
# 4

# %%
x_train
# Out:
#     mileage  age
# 12    59000    5
# 6     52000    5
# 3     22500    2
# 1     35000    3
# 18    87600    8
# 0     69000    6
# 8     91000    8
# 13    58780    4
# 4     46000    4
# 9     67000    6
# 2     57000    5
# 16    28000    2
# 19    52000    5
# 15    25400    3
# 10    83000    7
# 5     59000    5

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([25459.43958399, 16657.34376357, 22473.86203566, 13671.76621524])

# %%
y_test #Actual ans
# Out:
# 12    26000
# 10    18700
# 9     22000
# 8     12000
# Name: price, dtype: int64

# %%
clf.score(x_train, y_train) #Accuracy
# Out:
# 0.9256741321727423
